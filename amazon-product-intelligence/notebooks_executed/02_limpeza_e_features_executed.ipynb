# %% [markdown]
# # 02 — Limpeza e Feature Engineering
#
# Este notebook limpa campos numéricos, extrai categorias, cria features derivadas e salva os CSVs em `data/processed/`.

# %%
from __future__ import annotations

from pathlib import Path
import sys

import pandas as pd

PROJECT_DIR = Path.cwd().resolve()
while PROJECT_DIR.name != 'amazon-product-intelligence' and PROJECT_DIR.parent != PROJECT_DIR:
    PROJECT_DIR = PROJECT_DIR.parent

DATA_RAW = PROJECT_DIR / 'data' / 'raw' / 'dados_amazon.csv'
PROCESSED_DIR = PROJECT_DIR / 'data' / 'processed'
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

sys.path.insert(0, str(PROJECT_DIR / 'notebooks'))
from src.preprocessing import build_processed_datasets
# Out:
# C:\Users\flavi\Anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Gerar bases processadas

# %%
df_reviews, df_products = build_processed_datasets(DATA_RAW, PROCESSED_DIR)
(df_reviews.shape, df_products.shape)
# Out:
# ((1465, 27), (1351, 17))

# %% [markdown]
# ## Checagens rápidas

# %%
df_products[['product_id','product_name','main_category','sub_category','discounted_price_clean','actual_price_clean','discount_pct_clean','rating_clean','rating_count_clean','economia_absoluta','faixa_preco','faixa_desconto','volume_reviews_bin']].head(5)
# Out:
#    product_id                                       product_name  \
# 0  B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1  B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 2  B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 3  B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# 4  B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
#
#            main_category                             sub_category  \
# 0  Computers&Accessories                        NetworkingDevices
# 1  Computers&Accessories                        NetworkingDevices
# 2            Electronics  GeneralPurposeBatteries&BatteryChargers
# 3  Computers&Accessories                  Accessories&Peripherals
# 4  Computers&Accessories                  Accessories&Peripherals
#
#    discounted_price_clean  actual_price_clean  discount_pct_clean  \
# 0                   507.0              1208.0                58.0
# ...

# %%
df_products['main_category'].value_counts().head(10)
# Out:
# main_category
# Electronics              490
# Home&Kitchen             448
# Computers&Accessories    375
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Health&PersonalCare        1
# Car&Motorbike              1
# Name: count, dtype: int64

# %% [markdown]
# ## Artefatos gerados

# %%
sorted([p.name for p in PROCESSED_DIR.glob('*.csv')])
# Out:
# ['base_com_sentimento.csv',
#  'base_processada.csv',
#  'base_produtos.csv',
#  'base_produtos_com_clusters.csv',
#  'base_produtos_psi.csv']
